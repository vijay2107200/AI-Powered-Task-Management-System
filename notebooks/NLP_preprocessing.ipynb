# %% [markdown]
# # Week-1 NLP-**preprocessing**
# Project: AI-Powered Task Management System — Hospital Length of Stay Prediction Dataset: AV Healthcare Analytics II (Kaggle) Prepared by: Thivahar Balasubramaniam

# %%
import pandas as pd
import re
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-c98aac48-bc12-4de7-9902-6b1e77b03b09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c98aac48-bc12-4de7-9902-6b1e77b03b09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 1. "Loading dataset and initializing NLP preprocessing environment"

# %%
df = pd.read_csv('train_clean.csv')
display(df.head())
# Out:
#    case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0        1         8              2              3                2
# 1        2         2              2              5                2
# 2        3        10              4              1                0
# 3        4        26              1              2                1
# 4        5        26              1              2                1
#
#    Available_Extra_Rooms_in_Hospital    Department Ward_Type Ward_Facility  \
# 0                                  3  radiotherapy         R             F
# 1                                  2  radiotherapy         S             F
# 2                                  2    anesthesia         S             E
# 3                                  2  radiotherapy         R             D
# 4                                  2  radiotherapy         S             D
#
#    Bed_Grade  patientid  City_Code_Patient Admission_Type Illness_Severity  \
# ...

# %% [markdown]
# ### 2.Selecting Text Columns

# %%
text_columns = [
    "Department",
    "Ward_Type",
    "Ward_Facility",
    "Admission_Type",
    "Illness_Severity",
    "Age",
    "Stay_Days"
]

df[text_columns].head()
# Out:
#      Department Ward_Type Ward_Facility Admission_Type Illness_Severity  \
# 0  radiotherapy         R             F      Emergency          Extreme
# 1  radiotherapy         S             F         Trauma          Extreme
# 2    anesthesia         S             E         Trauma          Extreme
# 3  radiotherapy         R             D         Trauma          Extreme
# 4  radiotherapy         S             D         Trauma          Extreme
#
#      Age Stay_Days
# 0  51-60      0-10
# 1  51-60     41-50
# 2  51-60     31-40
# 3  51-60     41-50
# 4  51-60     41-50

# %% [markdown]
# This section:
#
# Imports required Python libraries,
# Downloads NLTK resources,
# Loads the cleaned dataset,
# Displays dataset information,
# Identifies categorical text columns for NLP preprocessing.

# %% [markdown]
# # "Implement text preprocessing pipeline using tokenization and lemmatization"

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

# %%
for column in text_columns:
    df[column + "_Processed"] = df[column].apply(preprocess_text)

df.head()
# Out:
#    case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0        1         8              2              3                2
# 1        2         2              2              5                2
# 2        3        10              4              1                0
# 3        4        26              1              2                1
# 4        5        26              1              2                1
#
#    Available_Extra_Rooms_in_Hospital    Department Ward_Type Ward_Facility  \
# 0                                  3  radiotherapy         R             F
# 1                                  2  radiotherapy         S             F
# 2                                  2    anesthesia         S             E
# 3                                  2  radiotherapy         R             D
# 4                                  2  radiotherapy         S             D
#
#    Bed_Grade  ...    Age  Admission_Deposit Stay_Days Department_Processed  \
# ...

# %%
sample = "Emergency Department!!"

print(preprocess_text(sample))
# Out:
# emergency department

# %% [markdown]
# The preprocessing function performs:
#
# Lowercase conversion,
# Punctuation removal,
# Extra whitespace removal,
# Tokenization,
# Stopword removal,
# Lemmatization

# %% [markdown]
# # Display summary statistics for the numerical columns in df

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
display(df[numerical_cols].describe())
# Out:
#              case_id       Hospital  Hospital_type  Hospital_city  \
# count  318438.000000  318438.000000  318438.000000  318438.000000
# mean   159219.500000      18.318841       1.256841       4.771717
# std     91925.276847       8.633755       1.535712       3.102535
# min         1.000000       1.000000       0.000000       1.000000
# 25%     79610.250000      11.000000       0.000000       2.000000
# 50%    159219.500000      19.000000       1.000000       5.000000
# 75%    238828.750000      26.000000       2.000000       7.000000
# max    318438.000000      32.000000       6.000000      13.000000
#
#        Hospital_region  Available_Extra_Rooms_in_Hospital      Bed_Grade  \
# count    318438.000000                      318438.000000  318438.000000
# mean          0.778098                           3.197627       2.625585
# std           0.752527                           1.168171       0.873070
# min           0.000000                           0.000000       1.000000
# ...

# %%
# Display summary statistics for all columns
df.describe(include='all')
# Out:
#               case_id       Hospital  Hospital_type  Hospital_city  \
# count   318438.000000  318438.000000  318438.000000  318438.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean    159219.500000      18.318841       1.256841       4.771717
# std      91925.276847       8.633755       1.535712       3.102535
# min          1.000000       1.000000       0.000000       1.000000
# 25%      79610.250000      11.000000       0.000000       2.000000
# 50%     159219.500000      19.000000       1.000000       5.000000
# 75%     238828.750000      26.000000       2.000000       7.000000
# max     318438.000000      32.000000       6.000000      13.000000
#
#         Hospital_region  Available_Extra_Rooms_in_Hospital  Department  \
# count     318438.000000                      318438.000000      318438
# ...

# %%
df.to_csv("train_clean_nlp.csv", index=False)

print("NLP preprocessing completed successfully.")
# Out:
# NLP preprocessing completed successfully.
